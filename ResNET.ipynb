# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np
# from tensorflow.keras.models import Model

# %%
model = ResNet50(weights='imagenet')  # same weights we need which we got when trained on ImageNET dataset (when model was ResNET)
# Out:
# ...
# 102967424/102967424 [==============================] - 1s 0us/step

# %%
img_path = "/content/doggg.png"
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)
print('Predicted:', decode_predictions(preds, top=3)[0])
print("             (Number,Prediction,Percentage Accuracy)          (since it's softmax so all probablitities add up to 1)")
# Out:
# 1/1 [==============================] - 0s 207ms/step
# Predicted: [('n02108000', 'EntleBucher', 0.83069944), ('n02107908', 'Appenzeller', 0.118784316), ('n02107574', 'Greater_Swiss_Mountain_dog', 0.04266304)]
#              (Number,Prediction,Percentage Accuracy)          (since it's softmax so all probablitities add up to 1)
